# %% [markdown]
# # Using VISTool

# %%
from tm2048 import VISTool
from collections import Counter
import random 
alist = [random.randint(1, 10) for _ in range(1000)]
VISTool.plot_counter(Counter(alist))

# %% [markdown]
# # Using TMTool

# %%
from tm2048 import TMTool
tm = TMTool.TMTool()
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="f8a809e3-cca2-4a95-be47-052d7b28de99">Loading BokehJS ...</span>
#     </div>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 2
#       1 from tm2048 import TMTool
# ----> 2 tm = TMTool.TMTool()
#
# File ~/opt/anaconda3/envs/new_tm/lib/python3.9/site-packages/tm2048/TMTool.py:28, in TMTool.__init__(self)
#      26 self.stopwords_tw = self.__load_stopwords_file("stopwords_tw.txt")
#      27 self.stopwords_cn = self.__load_stopwords_file("stopwords_cn.txt")
# ---> 28 self.__info()
#
# AttributeError: 'TMTool' object has no attribute '_TMTool__info'

# %%
import pkg_resources
